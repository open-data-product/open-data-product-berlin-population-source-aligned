# %% [markdown]
# # Berlin Population (source-aligned) - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd        

# Read csv file
dataframe = pd.read_csv("./data/03-gold/berlin-population-2025-01-csv/berlin-population-2025-01-t4-planning-areas.csv")

# %%
# Display 5 first rows
dataframe.head()
# Out:
#         id  ...  inhabitants_from_undefined_percentage
# 0  1100101  ...                               5.565142
# 1  1100102  ...                               3.230148
# 2  1100103  ...                               3.704743
# 3  1100104  ...                               6.613047
# 4  1100205  ...                               1.846453
#
# [5 rows x 57 columns]

# %%
# Display dataframe info
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 57 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   id                                               542 non-null    int64
#  1   inhabitants                                      542 non-null    int64
#  2   inhabitants_from_european_union                  542 non-null    int64
#  3   inhabitants_from_france                          542 non-null    int64
#  4   inhabitants_from_greece                          542 non-null    int64
#  5   inhabitants_from_italy                           542 non-null    int64
#  6   inhabitants_from_austria                         542 non-null    int64
#  7   inhabitants_from_spain                           542 non-null    int64
#  8   inhabitants_from_poland                          542 non-null    int64
# ...

# %%
# Describe dataframe
dataframe.describe()
# Out:
#                  id  ...  inhabitants_from_undefined_percentage
# count  5.420000e+02  ...                             542.000000
# mean   6.547167e+06  ...                               4.921352
# std    3.362516e+06  ...                               3.132582
# min    1.100101e+06  ...                               0.000000
# 25%    3.601451e+06  ...                               2.159975
# 50%    6.300578e+06  ...                               4.628013
# 75%    9.301101e+06  ...                               6.733198
# max    1.260124e+07  ...                              16.343919
#
# [8 rows x 57 columns]
